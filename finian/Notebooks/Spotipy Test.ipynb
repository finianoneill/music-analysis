# %%
# import dependencies
import requests
import spotipy
spotify = spotipy.Spotify()

# %%
# include variable for client ID and secret key encoded in base64
encoded_string = "ZTU2ZTg4NDQxOTgzNDE5MWExOTVmMGI2MjBkZGVhZjQ6MDUzZjU4OWU0MTU2NGEwNzliYTk5MTk0YmI0YjJlOGQ="

# %%
# create dictionary for spotify request
headers = {
    'Authorization': 'Basic ' + encoded_string,
}
# create list with client credential parameters
data = [
  ('grant_type', 'client_credentials'),
]
# create spotify response
spotify_response_json = requests.post('https://accounts.spotify.com/api/token', headers=headers, data=data).json()
# get spotify access token
spotify_access_token = spotify_response_json["access_token"]
print(spotify_access_token)
# Out:
# BQASSBBymuE14ttnsyAgXBJ8yWGWAgg7H_TaRGBWSD9TiQmOw4YR1YpTPHZbGm5CNCmZliUbICDg7yBbxtU

# %%
# get list of genres in spotify
token_headers = {
    'Authorization': 'Bearer ' + spotify_access_token
}

spotify_genres_json = requests.get('https://api.spotify.com/v1/recommendations/available-genre-seeds', headers=token_headers).json()

spotify_genres_json
# Out:
# {'genres': ['acoustic',
#   'afrobeat',
#   'alt-rock',
#   'alternative',
#   'ambient',
#   'anime',
#   'black-metal',
#   'bluegrass',
#   'blues',
#   'bossanova',
#   'brazil',
#   'breakbeat',
#   'british',
#   'cantopop',
#   'chicago-house',
#   'children',
#   'chill',
#   'classical',
#   'club',
#   'comedy',
#   'country',
#   'dance',
#   'dancehall',
#   'death-metal',
#   'deep-house',
#   'detroit-techno',
#   'disco',
#   'disney',
#   'drum-and-bass',
#   'dub',
#   'dubstep',
#   'edm',
#   'electro',
#   'electronic',
#   'emo',
#   'folk',
#   'forro',
#   'french',
#   'funk',
#   'garage',
#   'german',
#   'gospel',
#   'goth',
#   'grindcore',
#   'groove',
#   'grunge',
#   'guitar',
#   'happy',
#   'hard-rock',
#   'hardcore',
#   'hardstyle',
#   'heavy-metal',
#   'hip-hop',
#   'holidays',
#   'honky-tonk',
#   'house',
#   'idm',
#   'indian',
#   'indie',
#   'indie-pop',
#   'industrial',
#   'iranian',
#   'j-dance',
#   'j-idol',
#   'j-pop',
# ...
